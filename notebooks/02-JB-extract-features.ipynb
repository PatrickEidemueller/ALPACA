# %%
import pandas as pd

# %%
from src.features.smiles_to_feature_vector import generate_feature_vectors_from_smiles

# %%
import numpy as np

# %% [markdown]
# # ESOL-Features

# %%
df_esol = pd.read_csv("../data/raw/esol.csv")

# %%
df_features = df_esol.drop(['Compound ID', "ESOL predicted log solubility in mols per litre", "smiles"],axis=1)

# %%
df_features = df_features.rename(columns={'measured log solubility in mols per litre': 'y'})

# %%
df_features.to_csv("esol_features_6dims.csv")

# %%
df_features
# Out:
#       Minimum Degree  Molecular Weight  Number of H-Bond Donors  \
# 0                  1           457.432                        7
# 1                  1           201.225                        1
# 2                  1           152.237                        0
# 3                  2           278.354                        0
# 4                  2            84.143                        0
# ...              ...               ...                      ...
# 1123               1           197.381                        0
# 1124               1           219.266                        1
# 1125               1           246.359                        0
# 1126               1            72.151                        0
# 1127               1           365.964                        0
#
#       Number of Rings  Number of Rotatable Bonds  Polar Surface Area      y
# 0                   3                          7              202.32 -0.770
# 1                   2                          2               42.24 -3.300
# 2                   0                          4               17.07 -2.060
# 3                   5                          0                0.00 -7.870
# 4                   1                          0                0.00 -1.330
# ...               ...                        ...                 ...    ...
# 1123                0                          0                0.00 -1.710
# 1124                0                          1               71.00  0.106
# 1125                0                          7               18.46 -3.091
# 1126                0                          1                0.00 -3.180
# 1127                1                          5               44.76 -4.522
#
# [1128 rows x 7 columns]

# %%
import os
from rdkit import Chem
from gensim.models import word2vec
from mol2vec.features import mol2alt_sentence

# %%
def generate_mol_feature_vector(smiles, model, threshold):
    # count the nr of identifiers or substructures which are found in the pretrained model
    all_identifiers = mol2alt_sentence(Chem.MolFromSmiles(smiles), 1)
    existing_identifiers = [id for id in all_identifiers if id in model.wv]
    ratio_existing = len(existing_identifiers) / len(all_identifiers)
    if ratio_existing < threshold:
        return np.full((1,100), np.NaN)

    # get_mean_vector returns the mean of all the vectors for the given identifiers
    # return vector as pd.DataFrame with one row
    return model.wv.get_mean_vector(existing_identifiers).T

# %%
model = word2vec.Word2Vec.load("../models/model_100dim.pkl")

# %% [markdown]
# # Lipophilicity

# %%
df_lip = pd.read_csv("../data/raw/Lipophilicity.csv")

# %%
vecs = df_lip.smiles.apply(generate_mol_feature_vector, model=model, threshold=1)

# %%
df_lipo_mol2vec = pd.DataFrame(vecs.to_list())

# %%
df_lipo_mol2vec = df_lipo_mol2vec.dropna()

# %%
df_lipo_mol2vec = df_lipo_mol2vec.join(df_lip["exp"]).rename({"exp": "y"})

# %%
df_lipo_mol2vec.to_csv("../data/processed/lipo_mol2vec_100dims.csv")

# %% [markdown]
# ## Morgan pca

# %%
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect
from sklearn.decomposition import PCA

# %%
def get_morgan(smiles, dims=100):
    return np.array(GetMorganFingerprintAsBitVect(Chem.MolFromSmiles(smiles), 2))
morgan_df = pd.DataFrame(df_lip.smiles.apply(get_morgan).to_list())
pca = PCA(n_components=100)
morgan_pca = pca.fit_transform(morgan_df.to_numpy())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Studium/ds3/projekt/code/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/Studium/ds3/projekt/code/.venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Studium/ds3/projekt/code/.venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'expt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [9], line 6
#       4 pca = PCA(n_components=100)
#       5 morgan_pca = pca.fit_transform(morgan_df.to_numpy())
# ----> 6 df_morgan_pca = pd.DataFrame(morgan_pca).join(df_lip["expt"]).rename(columns={"expt": "y"})
#       7 df_morgan_pca.to_csv("../data/processed/lipo_pca_100dims.csv")
#
# File ~/Studium/ds3/projekt/code/.venv/lib/python3.10/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File ~/Studium/ds3/projekt/code/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'expt'

# %%
df_morgan_pca = pd.DataFrame(morgan_pca).join(df_lip["exp"]).rename(columns={"exp": "y"})
df_morgan_pca.to_csv("../data/processed/lipo_pca_100dims.csv")

# %% [markdown]
# # SAMPL

# %% [markdown]
# ## mol2vec

# %%
df_sampl = pd.read_csv("../data/raw/SAMPL.csv")

# %%
vecs = df_sampl.smiles.apply(generate_mol_feature_vector, model=model, threshold=1)

# %%
df_sampl_mol2vec = pd.DataFrame(vecs.to_list())

# %%
df_sampl_mol2vec = df_sampl_mol2vec.dropna()

# %%
df_sampl_mol2vec = df_sampl_mol2vec.join(df_sampl["expt"]).rename(columns={"expt": "y"})

# %%
df_sampl_mol2vec
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.016214  0.012790 -0.017872 -0.028390 -0.042108 -0.051491 -0.083414
# 2    0.049608  0.014997 -0.059075  0.041484 -0.029408 -0.113015 -0.027773
# 3    0.011491  0.012471 -0.064186  0.009589 -0.065068 -0.038959 -0.057275
# 4    0.092693  0.010417  0.003927  0.010841 -0.055614 -0.079625 -0.094156
# 5    0.002142  0.046737 -0.057976 -0.044081 -0.075069 -0.038647 -0.084356
# ..        ...       ...       ...       ...       ...       ...       ...
# 637  0.082068 -0.002458  0.006856  0.005336 -0.028064 -0.098318 -0.087953
# 638  0.061097  0.045054  0.065500 -0.085900 -0.070617 -0.025826 -0.033477
# 639 -0.003687  0.029495 -0.086191 -0.033442 -0.086723 -0.040470 -0.066362
# 640  0.084672  0.014277  0.013805  0.028286 -0.040380 -0.078853 -0.082111
# 641 -0.011839  0.017051  0.027636 -0.054897 -0.035388  0.035623 -0.046948
#
#             7         8         9  ...        91        92        93  \
# 0   -0.109482 -0.073367 -0.094714  ...  0.026665  0.011694 -0.092414
# 2   -0.047708  0.033426 -0.056274  ... -0.018149  0.083356 -0.091566
# 3   -0.074527 -0.049159 -0.123039  ...  0.072520 -0.048585 -0.091947
# 4   -0.074355 -0.032279 -0.102059  ...  0.082309  0.069291 -0.234453
# 5   -0.068500 -0.059625 -0.100704  ...  0.048821 -0.056462 -0.084724
# ..        ...       ...       ...  ...       ...       ...       ...
# 637 -0.099401 -0.054404 -0.062015  ...  0.052204  0.067428 -0.172817
# 638 -0.046722  0.000595 -0.089824  ...  0.008996 -0.101969 -0.062587
# 639 -0.068041 -0.040690 -0.093902  ...  0.026486 -0.032759 -0.128811
# 640 -0.050337 -0.053138 -0.109502  ...  0.092574  0.048336 -0.205517
# 641 -0.047676  0.035238 -0.147148  ...  0.075852 -0.084787 -0.013231
#
#            94        95        96        97        98        99      y
# 0    0.101662 -0.168516  0.016477  0.157401 -0.094769 -0.019061 -11.01
# 2    0.065267 -0.072673  0.042162  0.140899 -0.200474  0.017231   1.83
# 3    0.071382 -0.155135  0.003637  0.107502 -0.094570 -0.009354  -5.45
# 4    0.067601 -0.075477 -0.034403  0.072965 -0.149033 -0.062987  -4.21
# 5    0.152715 -0.205727 -0.027942  0.184688 -0.082949 -0.009053  -6.27
# ..        ...       ...       ...       ...       ...       ...    ...
# 637  0.070968 -0.091630  0.026654  0.105211 -0.125781 -0.038776  -2.04
# 638  0.024075 -0.152772  0.063236  0.056456 -0.162120  0.038816  -5.48
# 639  0.096059 -0.210208 -0.023171  0.170117 -0.095462 -0.040933  -8.83
# 640  0.063352 -0.088814 -0.010362  0.075952 -0.122459 -0.053626   0.29
# 641  0.131194 -0.240850  0.067418  0.019048 -0.076020 -0.001416  -5.06
#
# [598 rows x 101 columns]

# %%
df_sampl_mol2vec.to_csv("../data/processed/sampl_mol2vec_100dims.csv")

# %% [markdown]
# ## Morgan pca

# %%
morgan_df = pd.DataFrame(df_sampl.smiles.apply(get_morgan).to_list())
pca = PCA(n_components=100)
morgan_pca = pca.fit_transform(morgan_df.to_numpy())
df_morgan_pca = pd.DataFrame(morgan_pca).join(df_sampl["expt"]).rename(columns={"expt": "y"})
df_morgan_pca.to_csv("../data/processed/sampl_pca_100dims.csv")
